# %%
# import required packages
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)

# Preprocess all train images
train_generator = train_data_gen.flow_from_directory(
        'data/train',   # Directory that contains all the trained images 
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# Preprocess all test images
validation_generator = validation_data_gen.flow_from_directory(
        'data/test',  #Directory that contains all the test images
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

# create model structure
emotion_model = Sequential()
 
# First CNN Layer
emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2))) # Picks up the maximum value from the pool and forms output
emotion_model.add(Dropout(0.25)) # To avoid overfitting

# Second CNN Layer
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu')) 
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25)) # To avoid overfitting


emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu')) # Fully connected neural layer
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

cv2.ocl.setUseOpenCL(False)

emotion_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.0001, decay=1e-6), metrics=['accuracy']) # Compiling the model

# Train the neural network/model
emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)

# save model structure in jason file
model_json = emotion_model.to_json()
with open('model/emotion_model.json', "w") as json_file:
    json_file.write(model_json)

# save trained model weight in .h5 file
emotion_model.save_weights('model/emotion_model.h5')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# C:\Users\Deepanshu\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# C:\Users\Deepanshu\AppData\Local\Temp\ipykernel_20684\330983305.py:52: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   emotion_model_info = emotion_model.fit_generator(
# Epoch 1/50
# 448/448 [==============================] - 140s 294ms/step - loss: 1.8019 - accuracy: 0.2590 - val_loss: 1.7217 - val_accuracy: 0.3281
# Epoch 2/50
# 448/448 [==============================] - 12s 26ms/step - loss: 1.6334 - accuracy: 0.3617 - val_loss: 1.5319 - val_accuracy: 0.4227
# Epoch 3/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.5246 - accuracy: 0.4169 - val_loss: 1.4680 - val_accuracy: 0.4403
# Epoch 4/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.4509 - accuracy: 0.4486 - val_loss: 1.3867 - val_accuracy: 0.4718
# Epoch 5/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.3849 - accuracy: 0.4695 - val_loss: 1.3335 - val_accuracy: 0.4954
# Epoch 6/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.3391 - accuracy: 0.4924 - val_loss: 1.2946 - val_accuracy: 0.5064
# Epoch 7/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.2955 - accuracy: 0.5117 - val_loss: 1.2702 - val_accuracy: 0.5233
# Epoch 8/50
# 448/448 [==============================] - 82s 184ms/step - loss: 1.2594 - accuracy: 0.5253 - val_loss: 1.2510 - val_accuracy: 0.5308
# Epoch 9/50
# 448/448 [==============================] - 43s 95ms/step - loss: 1.2275 - accuracy: 0.5407 - val_loss: 1.2257 - val_accuracy: 0.5372
# Epoch 10/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1987 - accuracy: 0.5512 - val_loss: 1.1927 - val_accuracy: 0.5458
# Epoch 11/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1676 - accuracy: 0.5643 - val_loss: 1.1719 - val_accuracy: 0.5582
# Epoch 12/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1430 - accuracy: 0.5744 - val_loss: 1.1663 - val_accuracy: 0.5626
# Epoch 13/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1185 - accuracy: 0.5822 - val_loss: 1.1408 - val_accuracy: 0.5688
# Epoch 14/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0963 - accuracy: 0.5916 - val_loss: 1.1379 - val_accuracy: 0.5755
# Epoch 15/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0744 - accuracy: 0.6028 - val_loss: 1.1387 - val_accuracy: 0.5656
# Epoch 16/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0525 - accuracy: 0.6081 - val_loss: 1.1081 - val_accuracy: 0.5875
# Epoch 17/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0299 - accuracy: 0.6178 - val_loss: 1.1012 - val_accuracy: 0.5931
# Epoch 18/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0096 - accuracy: 0.6265 - val_loss: 1.1026 - val_accuracy: 0.5864
# Epoch 19/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9884 - accuracy: 0.6325 - val_loss: 1.0896 - val_accuracy: 0.5978
# Epoch 20/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9675 - accuracy: 0.6414 - val_loss: 1.0930 - val_accuracy: 0.5935
# Epoch 21/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9462 - accuracy: 0.6504 - val_loss: 1.0809 - val_accuracy: 0.5965
# Epoch 22/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9252 - accuracy: 0.6561 - val_loss: 1.0667 - val_accuracy: 0.6069
# Epoch 23/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.9113 - accuracy: 0.6646 - val_loss: 1.0748 - val_accuracy: 0.6016
# Epoch 24/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8843 - accuracy: 0.6741 - val_loss: 1.0681 - val_accuracy: 0.6073
# Epoch 25/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8616 - accuracy: 0.6839 - val_loss: 1.0634 - val_accuracy: 0.6090
# Epoch 26/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8414 - accuracy: 0.6903 - val_loss: 1.0700 - val_accuracy: 0.6088
# Epoch 27/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8229 - accuracy: 0.6989 - val_loss: 1.0762 - val_accuracy: 0.6144
# Epoch 28/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8041 - accuracy: 0.7051 - val_loss: 1.0610 - val_accuracy: 0.6159
# Epoch 29/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7788 - accuracy: 0.7166 - val_loss: 1.0542 - val_accuracy: 0.6187
# Epoch 30/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7527 - accuracy: 0.7230 - val_loss: 1.0687 - val_accuracy: 0.6143
# Epoch 31/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7344 - accuracy: 0.7336 - val_loss: 1.0632 - val_accuracy: 0.6138
# Epoch 32/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7153 - accuracy: 0.7372 - val_loss: 1.0611 - val_accuracy: 0.6225
# Epoch 33/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6944 - accuracy: 0.7462 - val_loss: 1.0764 - val_accuracy: 0.6198
# Epoch 34/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6724 - accuracy: 0.7544 - val_loss: 1.0777 - val_accuracy: 0.6176
# Epoch 35/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6492 - accuracy: 0.7621 - val_loss: 1.0696 - val_accuracy: 0.6207
# Epoch 36/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6321 - accuracy: 0.7690 - val_loss: 1.0728 - val_accuracy: 0.6208
# Epoch 37/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6216 - accuracy: 0.7735 - val_loss: 1.0910 - val_accuracy: 0.6217
# Epoch 38/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5922 - accuracy: 0.7853 - val_loss: 1.0920 - val_accuracy: 0.6214
# Epoch 39/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5823 - accuracy: 0.7880 - val_loss: 1.0900 - val_accuracy: 0.6246
# Epoch 40/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5532 - accuracy: 0.7994 - val_loss: 1.1080 - val_accuracy: 0.6225
# Epoch 41/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5418 - accuracy: 0.8042 - val_loss: 1.1074 - val_accuracy: 0.6218
# Epoch 42/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5248 - accuracy: 0.8105 - val_loss: 1.1198 - val_accuracy: 0.6232
# Epoch 43/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5058 - accuracy: 0.8157 - val_loss: 1.1185 - val_accuracy: 0.6249
# Epoch 44/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4894 - accuracy: 0.8227 - val_loss: 1.1420 - val_accuracy: 0.6218
# Epoch 45/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4746 - accuracy: 0.8263 - val_loss: 1.1401 - val_accuracy: 0.6260
# Epoch 46/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4617 - accuracy: 0.8325 - val_loss: 1.1429 - val_accuracy: 0.6222
# Epoch 47/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4504 - accuracy: 0.8388 - val_loss: 1.1580 - val_accuracy: 0.6244
# Epoch 48/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4276 - accuracy: 0.8470 - val_loss: 1.1548 - val_accuracy: 0.6271
# Epoch 49/50
# 448/448 [==============================] - 11s 26ms/step - loss: 0.4172 - accuracy: 0.8493 - val_loss: 1.1599 - val_accuracy: 0.6296
# Epoch 50/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.4232 - accuracy: 0.8489 - val_loss: 1.1619 - val_accuracy: 0.6268
